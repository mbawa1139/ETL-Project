# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
accident_data = pd.read_csv('Accidents0515.csv')
casualties_data = pd.read_csv('Casualties0515.csv')
vehicle_data = pd.read_csv('Vehicles0515.csv')
accident_data
# Out:
#         Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0        200501BS00001               525680.0                178240.0
# 1        200501BS00002               524170.0                181650.0
# 2        200501BS00003               524520.0                182240.0
# 3        200501BS00004               526900.0                177530.0
# 4        200501BS00005               528060.0                179040.0
# ...                ...                    ...                     ...
# 1780648  2015984139115               312087.0                570791.0
# 1780649  2015984139715               320671.0                569791.0
# 1780650  2015984140215               311731.0                586343.0
# 1780651  2015984140515               328273.0                570137.0
# 1780652  2015984141415               314050.0                579638.0
#
#          Longitude   Latitude  Police_Force  Accident_Severity  \
# ...

# %%
casualties_data.loc[casualties_data.Sex_of_Casualty == 1, 'Sex_of_Casualty'] = "Male"
casualties_data.loc[casualties_data.Sex_of_Casualty == 2, 'Sex_of_Casualty'] = "Female"
casualties_data.loc[casualties_data.Sex_of_Casualty == 3, 'Sex_of_Casualty'] = "Not known"
casualties_data.loc[casualties_data.Sex_of_Casualty == -1, 'Sex_of_Casualty'] = "Data missing or out of range"
casualties_data
# Out:
#         Accident_Index  Vehicle Reference  Casualty_Reference  Casualty_Class  \
# 0        200501BS00001                  1                   1               3
# 1        200501BS00002                  1                   1               2
# 2        200501BS00003                  2                   1               1
# 3        200501BS00004                  1                   1               3
# 4        200501BS00005                  1                   1               1
# ...                ...                ...                 ...             ...
# 1048570  200905EE31672                  1                   1               1
# 1048571  200905EE31672                  1                   2               2
# 1048572  200905EE31674                  2                   1               1
# 1048573  200905EE31680                  1                   1               1
# 1048574  200905EE31682                  1                   1               1
#
# ...

# %%
vehicle_data.loc[vehicle_data.Vehicle_Type == 2, 'Vehicle_Type'] = "Motorcycles"
vehicle_data.loc[vehicle_data.Vehicle_Type == 3, 'Vehicle_Type'] = "Motorcycles"
vehicle_data.loc[vehicle_data.Vehicle_Type == 4, 'Vehicle_Type'] = "Motorcycles"
vehicle_data.loc[vehicle_data.Vehicle_Type == 5, 'Vehicle_Type'] = "Motorcycles"
vehicle_data
# Out:
#         Accident_Index  Vehicle Reference Vehicle_Type  \
# 0        200501BS00001                  1            9
# 1        200501BS00002                  1           11
# 2        200501BS00003                  1           11
# 3        200501BS00003                  2            9
# 4        200501BS00004                  1            9
# ...                ...                ...          ...
# 1048570    2.00798E+12                  4           19
# 1048571    2.00798E+12                  1            9
# 1048572    2.00798E+12                  1           21
# 1048573    2.00798E+12                  2           19
# 1048574    2.00798E+12                  1            9
#
#          Towing_and_Articulation  Vehicle_Manoeuvre  \
# 0                              0                 18
# 1                              0                  4
# 2                              0                 17
# 3                              0                  2
# ...

# %%
new_vehicle_data = vehicle_data.loc[vehicle_data.Vehicle_Type == "Motorcycles"]
new_vehicle_data
# Out:
#         Accident_Index  Vehicle Reference Vehicle_Type  \
# 5        200501BS00005                  1  Motorcycles
# 7        200501BS00006                  2  Motorcycles
# 8        200501BS00007                  1  Motorcycles
# 17       200501BS00014                  2  Motorcycles
# 21       200501BS00017                  1  Motorcycles
# ...                ...                ...          ...
# 1048530    2.00798E+12                  1  Motorcycles
# 1048534    2.00798E+12                  1  Motorcycles
# 1048536    2.00798E+12                  1  Motorcycles
# 1048550    2.00798E+12                  1  Motorcycles
# 1048567    2.00798E+12                  1  Motorcycles
#
#          Towing_and_Articulation  Vehicle_Manoeuvre  \
# 5                              0                 18
# 7                              0                 18
# 8                              0                 18
# 17                             0                 18
# ...

# %%
dbv = new_vehicle_data[["Accident_Index", "Vehicle_Type"]]
dbv
# Out:
#         Accident_Index Vehicle_Type
# 5        200501BS00005  Motorcycles
# 7        200501BS00006  Motorcycles
# 8        200501BS00007  Motorcycles
# 17       200501BS00014  Motorcycles
# 21       200501BS00017  Motorcycles
# ...                ...          ...
# 1048530    2.00798E+12  Motorcycles
# 1048534    2.00798E+12  Motorcycles
# 1048536    2.00798E+12  Motorcycles
# 1048550    2.00798E+12  Motorcycles
# 1048567    2.00798E+12  Motorcycles
#
# [74525 rows x 2 columns]

# %%
dbc = casualties_data[["Accident_Index", "Sex_of_Casualty", "Age_of_Casualty"]]
dbc
# Out:
#         Sex_of_Casualty  Age_of_Casualty
# 0                  Male               37
# 1                  Male               37
# 2                  Male               62
# 3                  Male               30
# 4                  Male               49
# ...                 ...              ...
# 1048570            Male               59
# 1048571          Female               57
# 1048572          Female               64
# 1048573          Female               52
# 1048574            Male               23
#
# [1048575 rows x 2 columns]

# %%
dba = accident_data[["Accident_Index","Longitude", "Latitude"]]
dba
# Out:
#         Accident_Index  Longitude   Latitude
# 0        200501BS00001  -0.191170  51.489096
# 1        200501BS00002  -0.211708  51.520075
# 2        200501BS00003  -0.206458  51.525301
# 3        200501BS00004  -0.173862  51.482442
# 4        200501BS00005  -0.156618  51.495752
# ...                ...        ...        ...
# 1780648  2015984139115  -3.376671  55.023855
# 1780649  2015984139715  -3.242159  55.016316
# 1780650  2015984140215  -3.387067  55.163502
# 1780651  2015984140515  -3.123385  55.020580
# 1780652  2015984141415  -3.348646  55.103676
#
# [1780653 rows x 3 columns]

# %%
db = "postgres:inder1980@localhost:5432/sunny"
engine = create_engine(f'postgresql://{db}')

engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...
